# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("covid19indiaapi.csv")
data
# Out:
#      cases_time_series__dailyconfirmed  cases_time_series__dailydeceased  \
# 0                                    1                                 0
# 1                                    0                                 0
# 2                                    0                                 0
# 3                                    1                                 0
# 4                                    1                                 0
# ..                                 ...                               ...
# 241                              82770                              1040
# 242                              69668                               775
# 243                              80500                              1178
# 244                              86748                              1179
# 245                              81693                              1096
#
#      cases_time_series__dailyrecovered cases_time_series__date  \
# ...

# %%
data.columns
# Out:
# Index(['cases_time_series__dailyconfirmed', 'cases_time_series__dailydeceased',
#        'cases_time_series__dailyrecovered', 'cases_time_series__date',
#        'cases_time_series__totalconfirmed', 'cases_time_series__totaldeceased',
#        'cases_time_series__totalrecovered', 'statewise__active',
#        'statewise__confirmed', 'statewise__deaths',
#        'statewise__deltaconfirmed', 'statewise__deltadeaths',
#        'statewise__deltarecovered', 'statewise__lastupdatedtime',
#        'statewise__migratedother', 'statewise__recovered', 'statewise__state',
#        'statewise__statecode', 'statewise__statenotes',
#        'tested__dailyrtpcrtests', 'tested__individualstestedperconfirmedcase',
#        'tested__positivecasesfromsamplesreported',
#        'tested__samplereportedtoday', 'tested__source', 'tested__source1',
#        'tested__source3', 'tested__testedasof', 'tested__testpositivityrate',
# ...

# %%
data.tail()
# Out:
#      cases_time_series__dailyconfirmed  cases_time_series__dailydeceased  \
# 241                              82770                              1040
# 242                              69668                               775
# 243                              80500                              1178
# 244                              86748                              1179
# 245                              81693                              1096
#
#      cases_time_series__dailyrecovered cases_time_series__date  \
# 241                              74691           27 September
# 242                              85194           28 September
# 243                              86150           29 September
# 244                              85274           30 September
# 245                              78646             01 October
#
#      cases_time_series__totalconfirmed  cases_time_series__totaldeceased  \
# 241                            6073359                             94990
# ...

# %%
data.describe()
# Out:
#        cases_time_series__dailyconfirmed  cases_time_series__dailydeceased  \
# count                         246.000000                        246.000000
# mean                        25983.609756                        403.325203
# std                         32039.848994                        429.074590
# min                             0.000000                          0.000000
# 25%                           337.750000                          7.750000
# 50%                          8450.000000                        222.000000
# 75%                         52623.750000                        800.500000
# max                         97860.000000                       2004.000000
#
#        cases_time_series__dailyrecovered  cases_time_series__totalconfirmed  \
# count                         246.000000                       2.460000e+02
# mean                        21742.418699                       1.171261e+06
# ...

# %%
data["cases_time_series__totalrecovered"].sum()
# Out:
# 214554162

# %% [markdown]
# # relating the variables with scatterplots

# %%
sns.relplot(x="cases_time_series__dailyconfirmed", y="cases_time_series__dailyrecovered", hue="cases_time_series__totalconfirmed",data=data)
# sns.pairplot(data)

# %%
sns.pairplot(data)
# Out:
# /Users/khaidemsandipsingha/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/khaidemsandipsingha/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# Error in callback <function flush_figures at 0x7fc8635653b0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# ...

# %%
data.columns
# Out:
# Index(['cases_time_series__dailyconfirmed', 'cases_time_series__dailydeceased',
#        'cases_time_series__dailyrecovered', 'cases_time_series__date',
#        'cases_time_series__totalconfirmed', 'cases_time_series__totaldeceased',
#        'cases_time_series__totalrecovered', 'statewise__active',
#        'statewise__confirmed', 'statewise__deaths',
#        'statewise__deltaconfirmed', 'statewise__deltadeaths',
#        'statewise__deltarecovered', 'statewise__lastupdatedtime',
#        'statewise__migratedother', 'statewise__recovered', 'statewise__state',
#        'statewise__statecode', 'statewise__statenotes',
#        'tested__dailyrtpcrtests', 'tested__individualstestedperconfirmedcase',
#        'tested__positivecasesfromsamplesreported',
#        'tested__samplereportedtoday', 'tested__source', 'tested__source1',
#        'tested__source3', 'tested__testedasof', 'tested__testpositivityrate',
# ...

# %%
sns.relplot(x='statewise__recovered',y='statewise__confirmed', kind='line', data=data)

# %%
sns.catplot(x='statewise__recovered',y='statewise__confirmed', data=data)
